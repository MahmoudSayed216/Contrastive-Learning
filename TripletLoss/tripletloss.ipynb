# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/Contrastive-Learning
# !git clone https://github.com/MahmoudSayed216/Contrastive-Learning.git
# Out:
# /kaggle/working
# Cloning into 'Contrastive-Learning'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 123 (delta 45), reused 98 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 25.54 MiB | 42.31 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# %cd "/kaggle/working/Contrastive-Learning/TripletLoss"
# !pwd
# Out:
# /kaggle/working/Contrastive-Learning/TripletLoss
# /kaggle/working/Contrastive-Learning/TripletLoss

# %%
# !python  train.py
# Out:
# 00:40:36 | INFO | Logging to logs/train_20260705_004036.log
# 00:40:36 | INFO | Using device: cuda
# 00:40:36 | INFO | Loading datasets...
# 00:40:55 | INFO |   [Epoch 1/30] Batch 187/937 | Batch Triplet Loss: 0.3409
# 00:41:04 | INFO |   [Epoch 1/30] Batch 374/937 | Batch Triplet Loss: 0.1009
# 00:41:14 | INFO |   [Epoch 1/30] Batch 561/937 | Batch Triplet Loss: 0.0285
# 00:41:23 | INFO |   [Epoch 1/30] Batch 748/937 | Batch Triplet Loss: 0.0564
# 00:41:33 | INFO |   [Epoch 1/30] Batch 935/937 | Batch Triplet Loss: 0.0296
# 00:41:42 | INFO | Epoch 1/30 | Train Triplet Loss: 0.1315 | Val Triplet Loss: 0.0451 | LR: 0.010000
# 00:41:42 | INFO |   KNN (k=5) -> Acc: 0.9718 | Precision (macro): 0.9719 | Recall (macro): 0.9714 | F1 (macro): 0.9716
# 00:41:42 | INFO |   -> New best model (val_loss=0.0451) saved to checkpoints/best_model.pt
# 00:41:51 | INFO |   [Epoch 2/30] Batch 187/937 | Batch Triplet Loss: 0.0566
# ...

# %%
# !zip -r /kaggle/working/triplet.zip "/kaggle/working/Contrastive-Learning/TripletLoss/checkpoints"
# Out:
#   adding: kaggle/working/Contrastive-Learning/TripletLoss/checkpoints/ (stored 0%)
#   adding: kaggle/working/Contrastive-Learning/TripletLoss/checkpoints/best_model.pt (deflated 8%)
#   adding: kaggle/working/Contrastive-Learning/TripletLoss/checkpoints/precision_recall_curve.csv (deflated 69%)
#   adding: kaggle/working/Contrastive-Learning/TripletLoss/checkpoints/roc_curve.csv (deflated 77%)
