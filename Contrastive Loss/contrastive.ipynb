# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/Contrastive-Learning
# !git clone https://github.com/MahmoudSayed216/Contrastive-Learning.git
# Out:
# /kaggle/working
# Cloning into 'Contrastive-Learning'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 101 (delta 36), reused 86 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (101/101), 14.42 MiB | 30.57 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# %cd "/kaggle/working/Contrastive-Learning/Contrastive Loss"
# !pwd
# Out:
# /kaggle/working/Contrastive-Learning/Contrastive Loss
# /kaggle/working/Contrastive-Learning/Contrastive Loss

# %%
# !python  train.py
# Out:
# 21:01:15 | INFO | Logging to logs/train_20260704_210115.log
# 21:01:16 | INFO | Using device: cuda
# 21:01:16 | INFO | Loading datasets...
# 21:01:34 | INFO |   [Epoch 1/30] Batch 187/937 | Batch Contrastive Loss: 0.0862
# 21:01:41 | INFO |   [Epoch 1/30] Batch 374/937 | Batch Contrastive Loss: 0.0721
# 21:01:48 | INFO |   [Epoch 1/30] Batch 561/937 | Batch Contrastive Loss: 0.0718
# 21:01:56 | INFO |   [Epoch 1/30] Batch 748/937 | Batch Contrastive Loss: 0.0515
# 21:02:03 | INFO |   [Epoch 1/30] Batch 935/937 | Batch Contrastive Loss: 0.0353
# 21:02:10 | INFO | Epoch 1/30 | Train Contrastive Loss: 0.1058 | Val Contrastive Loss: 0.0403 | LR: 0.010000
# 21:02:10 | INFO |   KNN (k=5) -> Acc: 0.9626 | Precision (macro): 0.9625 | Recall (macro): 0.9621 | F1 (macro): 0.9622
# 21:02:10 | INFO |   -> New best model (val_loss=0.0403) saved to checkpoints/best_model.pt
# 21:02:17 | INFO |   [Epoch 2/30] Batch 187/937 | Batch Contrastive Loss: 0.0260
# ...

# %%
# !zip -r /kaggle/working/contrastive.zip "/kaggle/working/Contrastive-Learning/Contrastive Loss/checkpoints"
# Out:
#   adding: kaggle/working/Contrastive-Learning/Contrastive Loss/checkpoints/ (stored 0%)
#   adding: kaggle/working/Contrastive-Learning/Contrastive Loss/checkpoints/precision_recall_curve.csv (deflated 69%)
#   adding: kaggle/working/Contrastive-Learning/Contrastive Loss/checkpoints/best_model.pt (deflated 7%)
#   adding: kaggle/working/Contrastive-Learning/Contrastive Loss/checkpoints/roc_curve.csv (deflated 71%)
